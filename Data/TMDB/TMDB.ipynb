# %%
import requests
import pandas as pd
import time
API_KEY = '738f8682fc5143163b145d03a2016b0b'  
BASE_URL = 'https://api.themoviedb.org/3'
IMG_BASE = 'https://image.tmdb.org/t/p/w500'

# Lấy danh sách phim top-rated từ TMDB
def get_top_rated_movies(total_movies=200):
    movies = []
    page = 1
    while len(movies) < total_movies:
        url = f"{BASE_URL}/movie/top_rated"
        params = {
            'api_key': API_KEY,
            'language': 'en-US',
            'page': page
        }
        response = requests.get(url, params=params)
        data = response.json()

        if 'results' not in data:
            print("Có lỗi khi gọi API:", data)
            break

        movies += data['results']
        page += 1
        time.sleep(0.2)  # Tránh bị rate limit (giới hạn gọi API)

    return movies[:total_movies]

# Lấy thông tin chi tiết phim
def get_movie_details(movie_id):
    url = f"{BASE_URL}/movie/{movie_id}"
    params = {
        'api_key': API_KEY,
        'append_to_response': 'credits'
    }
    response = requests.get(url, params=params)
    return response.json()

# Lưu thông tin phim vào CSV
def save_top_rated_to_csv(filename='top_200_movies.csv', total=200):
    top_movies = get_top_rated_movies(total)
    movie_list = []

    for idx, movie in enumerate(top_movies):
        print(f"Đang xử lý phim {idx+1}/{total}: {movie['title']}")
        details = get_movie_details(movie['id'])

        info = {
            'Title': details.get('title'),
            'Original Title': details.get('original_title'),
            'Overview': details.get('overview'),
            'Release Date': details.get('release_date'),
            'Genres': ', '.join([g['name'] for g in details.get('genres', [])]),
            'Runtime': details.get('runtime'),
            'Rating': details.get('vote_average'),
            'Vote Count': details.get('vote_count'),
            'Tagline': details.get('tagline'),
            'Poster Link': IMG_BASE + details['poster_path'] if details.get('poster_path') else '',
            'Backdrop Link': IMG_BASE + details['backdrop_path'] if details.get('backdrop_path') else '',
            'Budget': details.get('budget'),
            'Revenue': details.get('revenue'),
            'Language': details.get('original_language'),
            'Production Companies': ', '.join([c['name'] for c in details.get('production_companies', [])]),
            'Cast': ', '.join([cast['name'] for cast in details.get('credits', {}).get('cast', [])[:5]]),
            'Director': ', '.join([crew['name'] for crew in details.get('credits', {}).get('crew', []) if crew['job'] == 'Director']),
        }

        movie_list.append(info)
        time.sleep(0.2)  # Delay nhẹ giữa các requests

    # Ghi vào file CSV
    df = pd.DataFrame(movie_list)
    df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"✅ Đã lưu {len(movie_list)} phim vào file '{filename}'")

# Chạy chính
if __name__ == '__main__':
    save_top_rated_to_csv()
# Out:
# Đang xử lý phim 1/200: The Shawshank Redemption
# Đang xử lý phim 2/200: The Godfather
# Đang xử lý phim 3/200: The Godfather Part II
# Đang xử lý phim 4/200: Schindler's List
# Đang xử lý phim 5/200: 12 Angry Men
# Đang xử lý phim 6/200: Spirited Away
# Đang xử lý phim 7/200: Dilwale Dulhania Le Jayenge
# Đang xử lý phim 8/200: The Dark Knight
# Đang xử lý phim 9/200: The Green Mile
# Đang xử lý phim 10/200: Parasite
# Đang xử lý phim 11/200: Pulp Fiction
# Đang xử lý phim 12/200: Your Name.
# Đang xử lý phim 13/200: The Lord of the Rings: The Return of the King
# Đang xử lý phim 14/200: Forrest Gump
# Đang xử lý phim 15/200: The Good, the Bad and the Ugly
# Đang xử lý phim 16/200: GoodFellas
# Đang xử lý phim 17/200: Seven Samurai
# Đang xử lý phim 18/200: Interstellar
# Đang xử lý phim 19/200: Grave of the Fireflies
# Đang xử lý phim 20/200: Life Is Beautiful
# Đang xử lý phim 21/200: Fight Club
# Đang xử lý phim 22/200: Cinema Paradiso
# Đang xử lý phim 23/200: City of God
# Đang xử lý phim 24/200: Psycho
# Đang xử lý phim 25/200: The Lord of the Rings: The Fellowship of the Ring
# Đang xử lý phim 26/200: A Dog's Will
# Đang xử lý phim 27/200: Impossible Things
# Đang xử lý phim 28/200: One Flew Over the Cuckoo's Nest
# Đang xử lý phim 29/200: Gabriel's Inferno
# Đang xử lý phim 30/200: Harakiri
# Đang xử lý phim 31/200: Once Upon a Time in America
# Đang xử lý phim 32/200: The Lord of the Rings: The Two Towers
# Đang xử lý phim 33/200: Counterattack
# Đang xử lý phim 34/200: Spider-Man: Into the Spider-Verse
# Đang xử lý phim 35/200: Howl's Moving Castle
# Đang xử lý phim 36/200: The Empire Strikes Back
# Đang xử lý phim 37/200: Primal: Tales of Savagery
# Đang xử lý phim 38/200: A Silent Voice: The Movie
# Đang xử lý phim 39/200: Gabriel's Inferno: Part II
# Đang xử lý phim 40/200: Hope
# Đang xử lý phim 41/200: The Pianist
# Đang xử lý phim 42/200: Gabriel's Inferno: Part III
# Đang xử lý phim 43/200: Se7en
# Đang xử lý phim 44/200: Whiplash
# Đang xử lý phim 45/200: Radical
# Đang xử lý phim 46/200: Inception
# Đang xử lý phim 47/200: Rear Window
# Đang xử lý phim 48/200: The Legend of Hei
# Đang xử lý phim 49/200: Spider-Man: Across the Spider-Verse
# Đang xử lý phim 50/200: The Silence of the Lambs
# Đang xử lý phim 51/200: American History X
# Đang xử lý phim 52/200: Lucy Shimmers and the Prince of Peace
# Đang xử lý phim 53/200: High and Low
# Đang xử lý phim 54/200: The Wild Robot
# Đang xử lý phim 55/200: Dou kyu sei – Classmates
# Đang xử lý phim 56/200: Princess Mononoke
# Đang xử lý phim 57/200: Back to the Future
# Đang xử lý phim 58/200: The Quintessential Quintuplets Movie
# Đang xử lý phim 59/200: Ikiru
# Đang xử lý phim 60/200: A Brighter Summer Day
# Đang xử lý phim 61/200: Dead Poets Society
# Đang xử lý phim 62/200: Léon: The Professional
# Đang xử lý phim 63/200: Perfect Blue
# Đang xử lý phim 64/200: The Great Dictator
# Đang xử lý phim 65/200: Josee, the Tiger and the Fish
# Đang xử lý phim 66/200: Sunset Boulevard
# Đang xử lý phim 67/200: Dedicated to my ex
# Đang xử lý phim 68/200: Once Upon a Studio
# Đang xử lý phim 69/200: Given
# Đang xử lý phim 70/200: Once Upon a Time in the West
# Đang xử lý phim 71/200: Hotarubi no Mori e
# Đang xử lý phim 72/200: Modern Times
# Đang xử lý phim 73/200: We All Loved Each Other So Much
# Đang xử lý phim 74/200: Neon Genesis Evangelion: The End of Evangelion
# Đang xử lý phim 75/200: It's a Wonderful Life
# Đang xử lý phim 76/200: The Intouchables
# Đang xử lý phim 77/200: Apocalypse Now
# Đang xử lý phim 78/200: City Lights
# Đang xử lý phim 79/200: Miracle in Cell No. 7
# Đang xử lý phim 80/200: Violet Evergarden: The Movie
# Đang xử lý phim 81/200: Paths of Glory
# Đang xử lý phim 82/200: The Legend of 1900
# Đang xử lý phim 83/200: The Lion King
# Đang xử lý phim 84/200: Clouds
# Đang xử lý phim 85/200: Le Trou
# Đang xử lý phim 86/200: Flow
# Đang xử lý phim 87/200: Oldboy
# Đang xử lý phim 88/200: Rascal Does Not Dream of a Dreaming Girl
# Đang xử lý phim 89/200: Taylor Swift: Reputation Stadium Tour
# Đang xử lý phim 90/200: Klaus
# Đang xử lý phim 91/200: Life in a Year
# Đang xử lý phim 92/200: Five Feet Apart
# Đang xử lý phim 93/200: Avengers: Endgame
# Đang xử lý phim 94/200: I Want to Eat Your Pancreas
# Đang xử lý phim 95/200: Avengers: Infinity War
# Đang xử lý phim 96/200: The Boy, the Mole, the Fox and the Horse
# Đang xử lý phim 97/200: Come and See
# Đang xử lý phim 98/200: Green Book
# Đang xử lý phim 99/200: Evangelion: 3.0+1.0 Thrice Upon a Time
# Đang xử lý phim 100/200: Out of the Clear Blue Sky
# Đang xử lý phim 101/200: Mommy
# Đang xử lý phim 102/200: TAYLOR SWIFT | THE ERAS TOUR
# Đang xử lý phim 103/200: The Matrix
# Đang xử lý phim 104/200: Wolf Children
# Đang xử lý phim 105/200: Il Sorpasso
# Đang xử lý phim 106/200: Justice League Dark: Apokolips War
# Đang xử lý phim 107/200: Woman in the Dunes
# Đang xử lý phim 108/200: Saving Private Ryan
# Đang xử lý phim 109/200: Gladiator
# Đang xử lý phim 110/200: Puss in Boots: The Last Wish
# Đang xử lý phim 111/200: Inglourious Basterds
# Đang xử lý phim 112/200: Wolfwalkers
# Đang xử lý phim 113/200: Witness for the Prosecution
# Đang xử lý phim 114/200: The Handmaiden
# Đang xử lý phim 115/200: The Shining
# Đang xử lý phim 116/200: Demon Slayer -Kimetsu no Yaiba- The Movie: Mugen Train
# Đang xử lý phim 117/200: The Help
# Đang xử lý phim 118/200: Coco
# Đang xử lý phim 119/200: Star Wars
# Đang xử lý phim 120/200: The Prestige
# Đang xử lý phim 121/200: The Art of Racing in the Rain
# Đang xử lý phim 122/200: Shutter Island
# Đang xử lý phim 123/200: Ultraman: Rising
# Đang xử lý phim 124/200: My Mom Is a Character 3
# Đang xử lý phim 125/200: The Apartment
# Đang xử lý phim 126/200: Michael Jackson's Thriller
# Đang xử lý phim 127/200: Hacksaw Ridge
# Đang xử lý phim 128/200: Doctor Who: The Day of the Doctor
# Đang xử lý phim 129/200: Maquia: When the Promised Flower Blooms
# Đang xử lý phim 130/200: A Clockwork Orange
# Đang xử lý phim 131/200: The Seventh Seal
# Đang xử lý phim 132/200: Django Unchained
# Đang xử lý phim 133/200: Top Gun: Maverick
# Đang xử lý phim 134/200: Bicycle Thieves
# Đang xử lý phim 135/200: 20th Century Girl
# Đang xử lý phim 136/200: Tokyo Story
# Đang xử lý phim 137/200: Memento
# Đang xử lý phim 138/200: The Usual Suspects
# Đang xử lý phim 139/200: Investigation of a Citizen Above Suspicion
# Đang xử lý phim 140/200: Innocent Voices
# Đang xử lý phim 141/200: Persona
# Đang xử lý phim 142/200: The Kid
# Đang xử lý phim 143/200: Alien
# Đang xử lý phim 144/200: Hamilton
# Đang xử lý phim 145/200: Scarface
# Đang xử lý phim 146/200: The Departed
# Đang xử lý phim 147/200: Vertigo
# Đang xử lý phim 148/200: Black Clover: Sword of the Wizard King
# Đang xử lý phim 149/200: My Hero Academia: Heroes Rising
# Đang xử lý phim 150/200: Good Will Hunting
# Đang xử lý phim 151/200: Casablanca
# Đang xử lý phim 152/200: Steven Universe: The Movie
# Đang xử lý phim 153/200: Capernaum
# Đang xử lý phim 154/200: Dune: Part Two
# Đang xử lý phim 155/200: Piper
# Đang xử lý phim 156/200: The Truman Show
# Đang xử lý phim 157/200: Togo
# Đang xử lý phim 158/200: Singin' in the Rain
# Đang xử lý phim 159/200: Scenes from a Marriage
# Đang xử lý phim 160/200: The Shop Around the Corner
# Đang xử lý phim 161/200: Violet Evergarden: Eternity and the Auto Memory Doll
# Đang xử lý phim 162/200: My Friends
# Đang xử lý phim 163/200: Joker
# Đang xử lý phim 164/200: 8½
# Đang xử lý phim 165/200: Jujutsu Kaisen 0
# Đang xử lý phim 166/200: There's Still Tomorrow
# Đang xử lý phim 167/200: Taxi Driver
# Đang xử lý phim 168/200: Central Station
# Đang xử lý phim 169/200: Silenced
# Đang xử lý phim 170/200: Bound by Honor
# Đang xử lý phim 171/200: Full Metal Jacket
# Đang xử lý phim 172/200: Zack Snyder's Justice League
# Đang xử lý phim 173/200: Better Days
# Đang xử lý phim 174/200: Wonder
# Đang xử lý phim 175/200: Terminator 2: Judgment Day
# Đang xử lý phim 176/200: Wild Strawberries
# Đang xử lý phim 177/200: Reservoir Dogs
# Đang xử lý phim 178/200: Call Me by Your Name
# Đang xử lý phim 179/200: Stalker
# Đang xử lý phim 180/200: Red Beard
# Đang xử lý phim 181/200: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Đang xử lý phim 182/200: Double Indemnity
# Đang xử lý phim 183/200: Lock, Stock and Two Smoking Barrels
# Đang xử lý phim 184/200: The Father
# Đang xử lý phim 185/200: Portrait of a Lady on Fire
# Đang xử lý phim 186/200: Soul
# Đang xử lý phim 187/200: “The Shorts” by Aldo, Giovanni and Giacomo
# Đang xử lý phim 188/200: Metropolis
# Đang xử lý phim 189/200: Palmer
# Đang xử lý phim 190/200: The Hate U Give
# Đang xử lý phim 191/200: The Great War
# Đang xử lý phim 192/200: Big Deal on Madonna Street
# Đang xử lý phim 193/200: The Best of Youth
# Đang xử lý phim 194/200: Green Snake
# Đang xử lý phim 195/200: In the Mood for Love
# Đang xử lý phim 196/200: The Invisible Guest
# Đang xử lý phim 197/200: Mortal Kombat Legends: Scorpion's Revenge
# Đang xử lý phim 198/200: Prisoners
# Đang xử lý phim 199/200: Incendies
# Đang xử lý phim 200/200: WALL·E
# ✅ Đã lưu 200 phim vào file 'top_200_movies.csv'
